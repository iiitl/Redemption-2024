# %% [markdown]
# <a href="https://colab.research.google.com/github/AMANVISHWAKARMA27/Redemption-2024/blob/RandomImage/Random_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
height = 240
width = 320
channels = 3

# %%
image = np.random.rand(height, width, channels)

# %%
plt.imshow(image)
plt.axis('off')
plt.show()
