# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Student_Performance.csv')
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
sns.barplot(data=df,x='Sleep Hours',y='Performance Index')
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Performance Index'>

# %%
sns.barplot(data=df,x='Hours Studied',y='Performance Index')
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
feature=['Hours Studied','Previous Scores','Sleep Hours','Sample Question Papers Practiced','Performance Index']
new_df=df[feature]
sns.heatmap(new_df.corr())
# Out:
# <Axes: >
