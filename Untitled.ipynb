# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('/content/prediction.csv')
df
# Out:
#     Unnamed: 0  area        prices
# 0            0  1000  3.164041e+05
# 1            1  1500  3.842979e+05
# 2            2  2300  4.929281e+05
# 3            3  3540  6.613048e+05
# 4            4  4120  7.400616e+05
# 5            5  4560  7.998082e+05
# 6            6  5490  9.260908e+05
# 7            7  3460  6.504418e+05
# 8            8  4750  8.256079e+05
# 9            9  2300  4.929281e+05
# 10          10  9000  1.402705e+06
# 11          11  8600  1.348390e+06
# 12          12  7100  1.144709e+06

# %%
Scaler = StandardScaler()
X = df.drop(columns=['prices'], axis=1)
Y = df['prices']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  13 non-null     int64
#  1   area        13 non-null     int64
#  2   prices      13 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 440.0 bytes

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=3)

# %%
standarized_type_price = Scaler.fit_transform(df['prices'].values.reshape(-1, 1))
print(standarized_type_price)
# Out:
# [[-1.40530229]
#  [-1.20104323]
#  [-0.87422875]
#  [-0.3676663 ]
#  [-0.13072579]
#  [ 0.04902217]
#  [ 0.42894401]
#  [-0.40034774]
#  [ 0.12664061]
#  [-0.87422875]
#  [ 1.86284256]
#  [ 1.69943532]
#  [ 1.08665816]]

# %%
standardize_X = Scaler.fit_transform(X)
print(standardize_X)
# Out:
# [[-1.60356745 -1.40530229]
#  [-1.33630621 -1.20104323]
#  [-1.06904497 -0.87422875]
#  [-0.80178373 -0.3676663 ]
#  [-0.53452248 -0.13072579]
#  [-0.26726124  0.04902217]
#  [ 0.          0.42894401]
#  [ 0.26726124 -0.40034774]
#  [ 0.53452248  0.12664061]
#  [ 0.80178373 -0.87422875]
#  [ 1.06904497  1.86284256]
#  [ 1.33630621  1.69943532]
#  [ 1.60356745  1.08665816]]

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (13, 2) (10, 2) (3, 2)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
input_values = [[50, 658]]

# %%
predicted_output = model.predict(input_values)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
loss_function_value = sum(abs(x - predicted_output) for x in input_values[0])

# %%
print("Predicted Output:", predicted_output)
print("Loss Function Value:", loss_function_value)
# Out:
# Predicted Output: [269964.7260274]
# Loss Function Value: [539221.4520548]
