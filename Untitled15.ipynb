# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import seaborn as sns
#import various libraries

# %%
df = pd.read_csv('CarsData.csv')

# %%
df.head()
# Out:
#    year  price  transmission  mileage  fuelType  tax   mpg  engineSize  \
# 0  2017   7495             1    11630         4  145  60.1         1.0
# 1  2017  10989             1     9200         4  145  58.9         1.0
# 2  2019  27990             3     1614         0  145  49.6         2.0
# 3  2017  12495             1    30960         0  150  62.8         2.0
# 4  2017   7999             1    19353         4  125  54.3         1.2
#
#    car_model_target_encoded
# 0               7718.184731
# 1              11318.725647
# 2              19445.345118
# 3              12756.576497
# 4              10190.856199

# %%
null_values = df.isnull().sum()
print(null_values)  #Check for null values in columns so i can handle that null values with different machine learning techniques like simple imputer or other
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Manufacturer    0
# dtype: int64

# %%
value_counts = df['model'].value_counts()

print("Unique values and their counts:")
print(value_counts)  #Check how many unique values I have so i can tell which data encoding technique I have to use for this categorical data
# Out:
# Unique values and their counts:
#  Fiesta     6509
#  Golf       4797
#  Focus      4555
#  C Class    3694
#  Corsa      3285
#             ...
# E Class        1
# 200            1
#  Ranger        1
# 180            1
# 220            1
# Name: model, Length: 196, dtype: int64

# %%
value_counts = df['Manufacturer'].value_counts()

print("Unique values and their counts:")
print(value_counts)  #Check how many unique values I have so i can tell which data encoding technique I have to use for this categorical data
# Out:
# Unique values and their counts:
# ford          17811
# volkswagen    14893
# vauxhall      13258
# merc          12860
# BMW           10664
# Audi          10565
# toyota         6699
# skoda          6188
# hyundi         4774
# Name: Manufacturer, dtype: int64

# %%
manufacturer_encoded = pd.get_dummies(df['Manufacturer'], prefix='Manufacturer')
#As there are only 9 values so we can easily use dummies technique to encode our categorical data very easily

# %%
car_model_target_mean = df.groupby('model')['price'].mean()
df['car_model_target_encoded'] = df['model'].map(car_model_target_mean)
#For the car model column with a large number of categories (196), we use target encoding.Encode each car model based on the mean of a target variable

# %%
df.drop(['Manufacturer', 'model'], axis=1, inplace=True)

# %%
df_encoded = pd.concat([df, manufacturer_encoded], axis=1)

# %%
df_encoded.head()
# Out:
#    year  price transmission  mileage fuelType  tax   mpg  engineSize  \
# 0  2017   7495       Manual    11630   Petrol  145  60.1         1.0
# 1  2017  10989       Manual     9200   Petrol  145  58.9         1.0
# 2  2019  27990    Semi-Auto     1614   Diesel  145  49.6         2.0
# 3  2017  12495       Manual    30960   Diesel  150  62.8         2.0
# 4  2017   7999       Manual    19353   Petrol  125  54.3         1.2
#
#    car_model_target_encoded  Manufacturer_Audi  Manufacturer_BMW  \
# 0               7718.184731                  0                 0
# 1              11318.725647                  0                 0
# 2              19445.345118                  0                 1
# 3              12756.576497                  0                 0
# 4              10190.856199                  0                 0
#
#    Manufacturer_ford  Manufacturer_hyundi  Manufacturer_merc  \
# 0                  0                    1                  0
# ...

# %%
label_encoder = LabelEncoder()
df['transmission'] = label_encoder.fit_transform(df['transmission'])
label_encoder = LabelEncoder()
df['fuelType'] = label_encoder.fit_transform(df['fuelType'])
#As we know both transmission and fueltype has very less unique values os I easily used label encoding for it to encode the data very easily and to get best result

# %%
corr = df_encoded.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
#Use Correlation matrix to see if there is any column i can drop but every column is giving there contribution in target
# Out:
# <ipython-input-44-50d9619b880b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df_encoded.corr()

# %%
y = df.iloc[:, 1].values
X = df.drop(columns=['price'])

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df_no_outliers = df[~((df < lower_bound) | (df > upper_bound)).any(axis=1)]
print("Number of outliers removed:", len(df) - len(df_no_outliers))
#Removed outliers ensures that the model is not overly influenced by extreme observations and give correct predicitions.
# Out:
# Number of outliers removed: 62273

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
def train_test_split(df, price, test_size=0.2):
    df = df.sample(frac=1, random_state=1)
    len_data = len(df)
    test_index = int(len_data * test_size)
    X_train = df.iloc[test_index:]
    X_test = df.iloc[:test_index].drop(columns=[price])
    y_train = X_train[price]
    y_test = df.iloc[:test_index][price]
    X_train = X_train.drop(columns=[price])
    return X_train, y_train, X_test, y_test

X_train, y_train, X_test, y_test = train_test_split(df, 'price')
print("X_train:", X_train)
print("y_train:", y_train)
print("X_test:", X_test)
print("y_test:", y_test)
# Out:
# X_train:        year  transmission  mileage  fuelType  tax   mpg  engineSize  \
# 62419  2019             1     7120         4  145  43.5         1.4
# 47475  2019             1     2728         4  150  43.5         1.5
# 27912  2017             1    25116         4  125  51.4         1.2
# 35419  2019             1     7773         4  145  57.7         1.0
# 91051  2017             0     8500         4  145  47.9         2.0
# ...     ...           ...      ...       ...  ...   ...         ...
# 21440  2016             1    19116         4  150  47.0         1.8
# 73349  2019             3     7848         0  145  68.9         1.5
# 50057  2015             3    14158         0  200  47.9         3.0
# 5192   2019             1       10         4  145  44.1         1.0
# 77708  2016             1    12444         4   30  55.0         1.3
#
#        car_model_target_encoded
# 62419               8115.796347
# 47475              22489.938272
# 27912              12756.576497
# ...

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (78170, 8) (19542, 8) (78170,) (19542,)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, BayesianRidge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import LinearSVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
models = {}

def train_validate_predict(regressor, x_train, y_train, x_test, y_test, index):
    model = regressor
    model.fit(x_train, y_train)

    y_pred = model.predict(x_test)

    r2 = r2_score(y_test, y_pred)
    models[index] = r2

# %%
model_list = [LinearRegression, Lasso, Ridge, BayesianRidge, DecisionTreeRegressor, LinearSVR,
              RandomForestRegressor,GradientBoostingRegressor]
model_names = ['Linear Regression', 'Lasso', 'Ridge', 'Bayesian Ridge', 'Decision Tree Regressor', 'Linear SVR',
                'Random Forest Regressor','GradientBosstingRegressor']

index = 0
for regressor in model_list:
    train_validate_predict(regressor(), X_train, y_train, X_test, y_test, model_names[index])
    index+=1
#use different models to check which has best r2_score
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
X.head()
# Out:
#    year  transmission  mileage  fuelType  tax   mpg  engineSize  \
# 0  2017             1    11630         4  145  60.1         1.0
# 1  2017             1     9200         4  145  58.9         1.0
# 2  2019             3     1614         0  145  49.6         2.0
# 3  2017             1    30960         0  150  62.8         2.0
# 4  2017             1    19353         4  125  54.3         1.2
#
#    car_model_target_encoded
# 0               7718.184731
# 1              11318.725647
# 2              19445.345118
# 3              12756.576497
# 4              10190.856199

# %%
models
# Out:
# {'Linear Regression': 0.832355091882186,
#  'Lasso': 0.8323641120661502,
#  'Ridge': 0.8323558317010771,
#  'Bayesian Ridge': 0.832357453139944,
#  'Decision Tree Regressor': 0.9320925052844556,
#  'Linear SVR': 0.730898094947445,
#  'Random Forest Regressor': 0.9573623903663049,
#  'GradientBosstingRegressor': 0.9262522314178924}
